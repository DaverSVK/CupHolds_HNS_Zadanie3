# %% [markdown]
# # Yolo 11 training

# %% [markdown]
# ### Inports

# %%
#pip install ultralytics
from ultralytics import YOLO
import matplotlib.pyplot as plt
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\david\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !unzip -q CupsDataset.zip -d /Zadanie_3/datasets
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
model = YOLO("yolo11s-seg.pt")

# Train the model
train_results = model.train(
    data="/datasets/data.yaml",  
    epochs=1,  
    imgsz=640, 
    device=0,  
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11s-seg.pt to 'yolo11s-seg.pt'...
#  18%|█▊        | 3.62M/19.7M [00:03<00:15, 1.07MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 model = YOLO("yolo11s-seg.pt")
#       3 # Train the model
#       4 train_results = model.train(
#       5     data="!unzip -q CupsDataset.zip -d /Zadanie_3/datasets",
#       6     epochs=1,
#       7     imgsz=640,
#       8     device=0,
#       9 )
#
# File c:\Users\david\Desktop\Code\DNN\DNNvenv\lib\site-packages\ultralytics\models\yolo\model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File c:\Users\david\Desktop\Code\DNN\DNNvenv\lib\site-packages\ultralytics\engine\model.py:145, in Model.__init__(self, model, task, verbose)
#     143     self._new(model, task=task, verbose=verbose)
#     144 else:
# --> 145     self._load(model, task=task)
#
# File c:\Users\david\Desktop\Code\DNN\DNNvenv\lib\site-packages\ultralytics\engine\model.py:285, in Model._load(self, weights, task)
#     282 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolov8n -> yolov8n.pt
#     284 if Path(weights).suffix == ".pt":
# --> 285     self.model, self.ckpt = attempt_load_one_weight(weights)
#     286     self.task = self.model.args["task"]
#     287     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File c:\Users\david\Desktop\Code\DNN\DNNvenv\lib\site-packages\ultralytics\nn\tasks.py:910, in attempt_load_one_weight(weight, device, inplace, fuse)
#     908 def attempt_load_one_weight(weight, device=None, inplace=True, fuse=False):
#     909     """Loads a single model weights."""
# --> 910     ckpt, weight = torch_safe_load(weight)  # load ckpt
#     911     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#     912     model = (ckpt.get("ema") or ckpt["model"]).to(device).float()  # FP32 model
#
# File c:\Users\david\Desktop\Code\DNN\DNNvenv\lib\site-packages\ultralytics\nn\tasks.py:815, in torch_safe_load(weight, safe_only)
#     812 from ultralytics.utils.downloads import attempt_download_asset
#     814 check_suffix(file=weight, suffix=".pt")
# --> 815 file = attempt_download_asset(weight)  # search online if missing locally
#     816 try:
#     817     with temporary_modules(
#     818         modules={
#     819             "ultralytics.yolo.utils": "ultralytics.utils",
#    (...)
#     827         },
#     828     ):
#
# File c:\Users\david\Desktop\Code\DNN\DNNvenv\lib\site-packages\ultralytics\utils\downloads.py:454, in attempt_download_asset(file, repo, release, **kwargs)
#     451         safe_download(url=url, file=file, min_bytes=1e5, **kwargs)
#     453 elif repo == GITHUB_ASSETS_REPO and name in GITHUB_ASSETS_NAMES:
# --> 454     safe_download(url=f"{download_url}/{release}/{name}", file=file, min_bytes=1e5, **kwargs)
#     456 else:
#     457     tag, assets = get_github_assets(repo, release)
#
# File c:\Users\david\Desktop\Code\DNN\DNNvenv\lib\site-packages\ultralytics\utils\downloads.py:341, in safe_download(url, file, dir, unzip, delete, curl, retry, min_bytes, exist_ok, progress)
#     339 method = "torch"
#     340 if method == "torch":
# --> 341     torch.hub.download_url_to_file(url, f, progress=progress)
#     342 else:
#     343     with request.urlopen(url) as response, TQDM(
#     344         total=int(response.getheader("Content-Length", 0)),
#     345         desc=desc,
#    (...)
#     349         unit_divisor=1024,
#     350     ) as pbar:
#
# File c:\Users\david\Desktop\Code\DNN\DNNvenv\lib\site-packages\torch\hub.py:658, in download_url_to_file(url, dst, hash_prefix, progress)
#     656 if len(buffer) == 0:
#     657     break
# --> 658 f.write(buffer)  # type: ignore[possibly-undefined]
#     659 if hash_prefix is not None:
#     660     sha256.update(buffer)  # type: ignore[possibly-undefined]
#
# KeyboardInterrupt:

# %%
model = YOLO("runs/segment/train/weights/best.pt")

results = model("customimages/cupiik3.png")

annotated_image = results[0].plot()  

plt.figure(figsize=(10, 10))
plt.imshow(annotated_image)
plt.axis('off')  
plt.title("YOLO Predictions")
plt.show()
# Out:
# image 1/1 c:\Users\david\Desktop\Code\DNN\Zadanie_3\customimages\cupiik3.png: 608x640 1 CupHold, 27.4ms
# Speed: 4.0ms preprocess, 27.4ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
